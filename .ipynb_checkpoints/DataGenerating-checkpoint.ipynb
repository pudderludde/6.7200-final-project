# %% [markdown]
# ## Case: Hospital
# Implenting data as it is stored in a relational database.

# %% [markdown]
# ### Employee data
# Need
# - Number of hours each employee is contracted to work
# - Hourly salary for each employee

# %%
using Pkg
Pkg.add("CSV")
Pkg.add("DataFrames")
Pkg.add("Random")
Pkg.add("Statistics")
Pkg.add("Dates")
Pkg.add("Gurobi");
Pkg.add("JuMP");
Pkg.add("Plots")
using CSV, DataFrames, Random, Statistics, Dates, Gurobi, JuMP, Plots;
# Out:
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.9/Project.toml`
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.9/Project.toml`
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.9/Project.toml`
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.9/Project.toml`
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.9/Project.toml`
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.9/Project.toml`
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.9/Project.toml`
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.9/Project.toml`
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`

# %%
FTE_rates = vcat(fill(1.0, 15), fill(0.75, 8), fill(0.7, 3), fill(0.5, 4))
Random.seed!(42)
wages = [round((randn() * 3.0 + 20) * rate, digits=2) for rate in FTE_rates]
employees = DataFrame(FTE_rate = FTE_rates, wage = wages);
CSV.write("data/employees.csv", employees)
employees
# Out:
# 30×2 DataFrame
#  Row │ FTE_rate  wage
#      │ Float64   Float64
# ─────┼───────────────────
#    1 │     1.0     22.37
#    2 │     1.0     17.36
#    3 │     1.0     17.38
#    4 │     1.0     17.8
#    5 │     1.0     17.89
#    6 │     1.0     19.78
#    7 │     1.0     17.26
#    8 │     1.0     21.89
#    9 │     1.0     24.32
#   10 │     1.0     18.94
#   11 │     1.0     22.39
#   ⋮  │    ⋮         ⋮
#   21 │     0.75    15.45
#   22 │     0.75    17.55
#   23 │     0.75    15.65
#   24 │     0.7     10.79
#   25 │     0.7     14.46
#   26 │     0.7     12.72
#   27 │     0.5     10.97
#   28 │     0.5     12.0
#   29 │     0.5      9.0
#   30 │     0.5      8.49
#            9 rows omitted

# %% [markdown]
# ### Shift data

# %%
num_shifts = 30  # number of shifts to generate
num_days = 28
start_dates = [Date(2024, 1, 1) + Day(i-1) for i in 1:num_days]
start_times = [Time(7,0), Time(15,0), Time(23,0) ]
shift_durations = [4,6,8,10]


shifts = DataFrame(date = Date[], start_time = Time[], duration = Float64[], required_workers = Int[])

Random.seed!(42)
for start_date in start_dates, start_time in start_times
    push!(shifts, (start_date, start_time, rand(shift_durations), rand(1:10)))
end
CSV.write("data/shifts.csv", shifts)
shifts
# Out:
# 84×4 DataFrame
#  Row │ date        start_time  duration  required_workers
#      │ Date        Time        Float64   Int64
# ─────┼────────────────────────────────────────────────────
#    1 │ 2024-01-01  07:00:00         8.0                 5
#    2 │ 2024-01-01  15:00:00         6.0                 8
#    3 │ 2024-01-01  23:00:00         8.0                 2
#    4 │ 2024-01-02  07:00:00         8.0                 7
#    5 │ 2024-01-02  15:00:00         6.0                 3
#    6 │ 2024-01-02  23:00:00         8.0                 7
#    7 │ 2024-01-03  07:00:00         6.0                 3
#    8 │ 2024-01-03  15:00:00         8.0                 1
#    9 │ 2024-01-03  23:00:00         6.0                 2
#   10 │ 2024-01-04  07:00:00         6.0                 5
#   11 │ 2024-01-04  15:00:00         4.0                 6
#   ⋮  │     ⋮           ⋮          ⋮             ⋮
#   75 │ 2024-01-25  23:00:00         4.0                 6
#   76 │ 2024-01-26  07:00:00         8.0                 4
#   77 │ 2024-01-26  15:00:00        10.0                 3
#   78 │ 2024-01-26  23:00:00         4.0                 6
#   79 │ 2024-01-27  07:00:00         4.0                 2
#   80 │ 2024-01-27  15:00:00        10.0                 1
#   81 │ 2024-01-27  23:00:00         6.0                 1
#   82 │ 2024-01-28  07:00:00        10.0                 5
#   83 │ 2024-01-28  15:00:00         4.0                 5
#   84 │ 2024-01-28  23:00:00         4.0                 5
#                                            63 rows omitted

# %% [markdown]
# ## Optimization
#
# Data

# %%
D = shifts[!,"required_workers"]
L = shifts[!,"duration"]
S = employees[!,"wage"]
R = employees[!,"FTE_rate"]
epsilon = 0.05
hours_in_month = 40*4

n = nrow(employees)
m = nrow(shifts)

model = Model(Gurobi.Optimizer)
@variable(model, Z[1:n], Bin) # Binary variable whether employee p should be included in schedule or not
@variable(model, X[1:n, 1:m], Bin)
@objective(model, Min, sum(sum(X[p,s]*L[s]*S[p] for s in 1:m) for p in 1:n))
@constraint(model, zx_constraint[p in 1:n, s in 1:m], X[p,s] <= Z[p])
@constraint(model, demand_constraint[s in 1:m], sum(X[p,s] for p in 1:n) >= D[s])
@constraint(model, FTE_lower_constraint[p in 1:n], sum(X[p,s]*L[s] for s in 1:m) >= R[p]*hours_in_month*(1-epsilon)*Z[p])
@constraint(model, FTE_upper_constraint[p in 1:n], sum(X[p,s]*L[s] for s in 1:m) <= R[p]*hours_in_month*(1+epsilon)*Z[p])
optimize!(model);
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-07
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2664 rows, 2550 columns and 12660 nonzeros
# Model fingerprint: 0x50bb6906
# Variable types: 0 continuous, 2550 integer (2550 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [3e+01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+01]
# Presolve time: 0.04s
# Presolved: 2664 rows, 2550 columns, 12660 nonzeros
# Variable types: 0 continuous, 2550 integer (2550 binary)
# Found heuristic solution: objective 67189.320000
# Found heuristic solution: objective 57076.360000
#
# Root relaxation: objective 4.757462e+04, 575 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 47574.6200    0   36 57076.3600 47574.6200  16.6%     -    0s
# H    0     0                    48452.280000 47574.6200  1.81%     -    0s
# H    0     0                    48407.500000 47574.6200  1.72%     -    0s
# H    0     0                    48303.940000 47574.6200  1.51%     -    0s
#      0     0 47574.6200    0   40 48303.9400 47574.6200  1.51%     -    0s
# H    0     0                    47869.740000 47574.6200  0.62%     -    0s
# H    0     0                    47866.620000 47574.6200  0.61%     -    0s
#      0     0 47574.6200    0   41 47866.6200 47574.6200  0.61%     -    0s
#      0     0 47574.6200    0   42 47866.6200 47574.6200  0.61%     -    0s
#      0     0 47588.1055    0   95 47866.6200 47588.1055  0.58%     -    0s
#      0     0 47705.8660    0  126 47866.6200 47705.8660  0.34%     -    0s
#      0     0 47705.8660    0  136 47866.6200 47705.8660  0.34%     -    0s
#      0     0 47705.8660    0  134 47866.6200 47705.8660  0.34%     -    0s
#      0     0 47705.8660    0  136 47866.6200 47705.8660  0.34%     -    0s
#      0     0 47705.8660    0  118 47866.6200 47705.8660  0.34%     -    0s
#      0     0 47770.3935    0   83 47866.6200 47770.3935  0.20%     -    0s
# H    0     0                    47866.440000 47770.3935  0.20%     -    0s
#      0     0 47784.6200    0   71 47866.4400 47784.6200  0.17%     -    0s
#      0     0 47842.6400    0   59 47866.4400 47842.6400  0.05%     -    0s
#      0     0 47842.6400    0   63 47866.4400 47842.6400  0.05%     -    0s
#      0     0 47842.6400    0   27 47866.4400 47842.6400  0.05%     -    0s
# H    0     0                    47863.560000 47842.6400  0.04%     -    0s
# H    0     0                    47858.960000 47842.6400  0.03%     -    0s
#      0     0     cutoff    0      47858.9600 47858.9600  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 1
#   Mod-K: 2
#
# Explored 1 nodes (7399 simplex iterations) in 0.70 seconds (0.48 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 47859 47859 47863.6 ... 57076.4
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.785896000000e+04, best bound 4.785896000000e+04, gap 0.0000%
#
# User-callback calls 621, time in user-callback 0.00 sec

# %%
X_opt = value.(X)
employees.nr_shifts = sum(X_opt, dims=2) |> vec
employees.hours = X_opt*L
employees
# Out:
# 30×4 DataFrame
#  Row │ FTE_rate  wage     nr_shifts  hours
#      │ Float64   Float64  Float64    Float64
# ─────┼───────────────────────────────────────
#    1 │     1.0      8.49        0.0      0.0
#    2 │     1.0      9.0        26.0    168.0
#    3 │     1.0     10.79       26.0    168.0
#    4 │     1.0     10.97       27.0    168.0
#    5 │     1.0     12.0        27.0    168.0
#    6 │     1.0     12.72       24.0    152.0
#    7 │     1.0     14.16       26.0    168.0
#    8 │     1.0     14.34        0.0      0.0
#    9 │     1.0     14.46        0.0      0.0
#   10 │     1.0     15.29       22.0    152.0
#   11 │     1.0     15.45        0.0      0.0
#   ⋮  │    ⋮         ⋮         ⋮         ⋮
#   21 │     0.75    17.89       17.0    126.0
#   22 │     0.75    18.22       17.0    126.0
#   23 │     0.75    18.94       20.0    126.0
#   24 │     0.7     19.78       17.0    116.0
#   25 │     0.7     21.29       14.0    116.0
#   26 │     0.7     21.89       17.0    116.0
#   27 │     0.5     22.37       12.0     84.0
#   28 │     0.5     22.39       11.0     84.0
#   29 │     0.5     22.86       12.0     84.0
#   30 │     0.5     24.32       12.0     84.0
#                                9 rows omitted

# %%
display(employees[employees.hours .== 0, :])

scatter(employees.wage, employees.hours, title="Wage vs. Number of shifts", 
    xlabel="Wage", ylabel="Number of shifts", legend=false)
# Out:
# 7×4 DataFrame
#  Row │ FTE_rate  wage     nr_shifts  hours
#      │ Float64   Float64  Float64    Float64
# ─────┼───────────────────────────────────────
#    1 │     1.0      8.49        0.0      0.0
#    2 │     1.0     14.34        0.0      0.0
#    3 │     1.0     14.46        0.0      0.0
#    4 │     1.0     15.45        0.0      0.0
#    5 │     1.0     16.47        0.0      0.0
#    6 │     1.0     17.26        0.0      0.0
#    7 │     0.75    17.63        0.0      0.0
